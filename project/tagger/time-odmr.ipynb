# %% [markdown]
# # Time-domain ODMR measurement (with APD & Time Tagger)

# %% [markdown]
# ![frequency-shceduling](../figure/time-scheduling.jpg)

# %% [markdown]
# Import necessary modules and functions firstly

# %%
import matplotlib.pyplot as plt
from odmactor.scheduler import RamseyScheduler, RabiScheduler, RelaxationScheduler
from odmactor.scheduler import HahnEchoScheduler
from odmactor.utils.plotting import plot_ramsey, plot_rabi, plot_t1
import scipy.constants as C
import numpy as np

# %% [markdown]
# ## Ramsey detection

# %% [markdown]
# **1. Set measurement parameters**
# - number of readout operation $N$ per frequency measurement point
# - delay time range for scanning modes, i.e., `[t_start, t_end, t_step]`, unit: "ns"
# - calibrated MW $\pi$ pulse parameters, i.e., frequency (unit: Hz), power (unit: dBm) and time (unit: s)
# - laser initialization time $t_{init}$, signal readout pulse time $t_{sig}$, etc.
# - optional parameters: MW power $p$, if designed, the time of built-in MW $\pi$ pulse will be regulated correspondingly
# - time bin $t$ per readout operation will be calculated dynamically when running the scheduler on scanning-time mode

# %%
t_start = 40
t_end = 7000
t_step = 30

pi_power = 12
pi_freq = 2.852 * C.giga
pi_time = 310 * C.nano

t_init = 5e3
inter_init_mw = 3e3
inter_mw_read = 200
pre_read = 50
t_read_sig = 800
# t_read_ref = t_read_sig

N = int(1e6 / 4)

# %% [markdown]
# **2. Construct a Ramsey Scheduler and run**
#
# Especially, the calibrated MW $\pi$ pulse should be configured

# %%
scheduler = RamseyScheduler(mw_ttl=1, with_ref=True, epoch_omit=5)
scheduler.configure_mw_paras(power=pi_power, freq=pi_freq)
scheduler.pi_pulse['freq'], scheduler.pi_pulse['power'], scheduler.pi_pulse['time'] = pi_freq, pi_power, pi_time
scheduler.configure_odmr_seq(t_init, t_read_sig, inter_init_mw=inter_init_mw, inter_mw_read=inter_mw_read,
                             pre_read=pre_read, N=N)
scheduler.set_delay_times(t_start, t_end, t_step)
scheduler.configure_tagger_counting(reader='cbm')
# Out:
# --- USE ASGDLL_x64.dll ---
# Current Tagger input channels: {'apd': 1, 'asg': 2}

# %%
scheduler.run_scanning()
scheduler.close()
# Out:
# Begin to run Ramsey Scheduler. Time intervals: 40.000 - 7000.000 ns.
# N: 250000, n_times: 233
# Estimated total running time: 205.04 s
# MW on/off status: True
# scanning freq 40.000 ns (trivial)
# scanning freq 40.000 ns (trivial)
# scanning freq 40.000 ns (trivial)
# scanning freq 40.000 ns (trivial)
# scanning freq 40.000 ns (trivial)
# scanning freq 40.000 ns
# scanning freq 70.000 ns
# scanning freq 100.000 ns
# scanning freq 130.000 ns
# scanning freq 160.000 ns
# scanning freq 190.000 ns
# scanning freq 220.000 ns
# scanning freq 250.000 ns
# scanning freq 280.000 ns
# scanning freq 310.000 ns
# scanning freq 340.000 ns
# scanning freq 370.000 ns
# scanning freq 400.000 ns
# scanning freq 430.000 ns
# scanning freq 460.000 ns
# scanning freq 490.000 ns
# scanning freq 520.000 ns
# scanning freq 550.000 ns
# scanning freq 580.000 ns
# scanning freq 610.000 ns
# scanning freq 640.000 ns
# scanning freq 670.000 ns
# scanning freq 700.000 ns
# scanning freq 730.000 ns
# scanning freq 760.000 ns
# scanning freq 790.000 ns
# scanning freq 820.000 ns
# scanning freq 850.000 ns
# scanning freq 880.000 ns
# scanning freq 910.000 ns
# scanning freq 940.000 ns
# scanning freq 970.000 ns
# scanning freq 1000.000 ns
# scanning freq 1030.000 ns
# scanning freq 1060.000 ns
# scanning freq 1090.000 ns
# scanning freq 1120.000 ns
# scanning freq 1150.000 ns
# scanning freq 1180.000 ns
# scanning freq 1210.000 ns
# scanning freq 1240.000 ns
# scanning freq 1270.000 ns
# scanning freq 1300.000 ns
# scanning freq 1330.000 ns
# scanning freq 1360.000 ns
# scanning freq 1390.000 ns
# scanning freq 1420.000 ns
# scanning freq 1450.000 ns
# scanning freq 1480.000 ns
# scanning freq 1510.000 ns
# scanning freq 1540.000 ns
# scanning freq 1570.000 ns
# scanning freq 1600.000 ns
# scanning freq 1630.000 ns
# scanning freq 1660.000 ns
# scanning freq 1690.000 ns
# scanning freq 1720.000 ns
# scanning freq 1750.000 ns
# scanning freq 1780.000 ns
# scanning freq 1810.000 ns
# scanning freq 1840.000 ns
# scanning freq 1870.000 ns
# scanning freq 1900.000 ns
# scanning freq 1930.000 ns
# scanning freq 1960.000 ns
# scanning freq 1990.000 ns
# scanning freq 2020.000 ns
# scanning freq 2050.000 ns
# scanning freq 2080.000 ns
# scanning freq 2110.000 ns
# scanning freq 2140.000 ns
# scanning freq 2170.000 ns
# scanning freq 2200.000 ns
# scanning freq 2230.000 ns
# scanning freq 2260.000 ns
# scanning freq 2290.000 ns
# scanning freq 2320.000 ns
# scanning freq 2350.000 ns
# scanning freq 2380.000 ns
# scanning freq 2410.000 ns
# scanning freq 2440.000 ns
# scanning freq 2470.000 ns
# scanning freq 2500.000 ns
# scanning freq 2530.000 ns
# scanning freq 2560.000 ns
# scanning freq 2590.000 ns
# scanning freq 2620.000 ns
# scanning freq 2650.000 ns
# scanning freq 2680.000 ns
# scanning freq 2710.000 ns
# scanning freq 2740.000 ns
# scanning freq 2770.000 ns
# scanning freq 2800.000 ns
# scanning freq 2830.000 ns
# scanning freq 2860.000 ns
# scanning freq 2890.000 ns
# scanning freq 2920.000 ns
# scanning freq 2950.000 ns
# scanning freq 2980.000 ns
# scanning freq 3010.000 ns
# scanning freq 3040.000 ns
# scanning freq 3070.000 ns
# scanning freq 3100.000 ns
# scanning freq 3130.000 ns
# scanning freq 3160.000 ns
# scanning freq 3190.000 ns
# scanning freq 3220.000 ns
# scanning freq 3250.000 ns
# scanning freq 3280.000 ns
# scanning freq 3310.000 ns
# scanning freq 3340.000 ns
# scanning freq 3370.000 ns
# scanning freq 3400.000 ns
# scanning freq 3430.000 ns
# scanning freq 3460.000 ns
# scanning freq 3490.000 ns
# scanning freq 3520.000 ns
# scanning freq 3550.000 ns
# scanning freq 3580.000 ns
# scanning freq 3610.000 ns
# scanning freq 3640.000 ns
# scanning freq 3670.000 ns
# scanning freq 3700.000 ns
# scanning freq 3730.000 ns
# scanning freq 3760.000 ns
# scanning freq 3790.000 ns
# scanning freq 3820.000 ns
# scanning freq 3850.000 ns
# scanning freq 3880.000 ns
# scanning freq 3910.000 ns
# scanning freq 3940.000 ns
# scanning freq 3970.000 ns
# scanning freq 4000.000 ns
# scanning freq 4030.000 ns
# scanning freq 4060.000 ns
# scanning freq 4090.000 ns
# scanning freq 4120.000 ns
# scanning freq 4150.000 ns
# scanning freq 4180.000 ns
# scanning freq 4210.000 ns
# scanning freq 4240.000 ns
# scanning freq 4270.000 ns
# scanning freq 4300.000 ns
# scanning freq 4330.000 ns
# scanning freq 4360.000 ns
# scanning freq 4390.000 ns
# scanning freq 4420.000 ns
# scanning freq 4450.000 ns
# scanning freq 4480.000 ns
# scanning freq 4510.000 ns
# scanning freq 4540.000 ns
# scanning freq 4570.000 ns
# scanning freq 4600.000 ns
# scanning freq 4630.000 ns
# scanning freq 4660.000 ns
# scanning freq 4690.000 ns
# scanning freq 4720.000 ns
# scanning freq 4750.000 ns
# scanning freq 4780.000 ns
# scanning freq 4810.000 ns
# scanning freq 4840.000 ns
# scanning freq 4870.000 ns
# scanning freq 4900.000 ns
# scanning freq 4930.000 ns
# scanning freq 4960.000 ns
# scanning freq 4990.000 ns
# scanning freq 5020.000 ns
# scanning freq 5050.000 ns
# scanning freq 5080.000 ns
# scanning freq 5110.000 ns
# scanning freq 5140.000 ns
# scanning freq 5170.000 ns
# scanning freq 5200.000 ns
# scanning freq 5230.000 ns
# scanning freq 5260.000 ns
# scanning freq 5290.000 ns
# scanning freq 5320.000 ns
# scanning freq 5350.000 ns
# scanning freq 5380.000 ns
# scanning freq 5410.000 ns
# scanning freq 5440.000 ns
# scanning freq 5470.000 ns
# scanning freq 5500.000 ns
# scanning freq 5530.000 ns
# scanning freq 5560.000 ns
# scanning freq 5590.000 ns
# scanning freq 5620.000 ns
# scanning freq 5650.000 ns
# scanning freq 5680.000 ns
# scanning freq 5710.000 ns
# scanning freq 5740.000 ns
# scanning freq 5770.000 ns
# scanning freq 5800.000 ns
# scanning freq 5830.000 ns
# scanning freq 5860.000 ns
# scanning freq 5890.000 ns
# scanning freq 5920.000 ns
# scanning freq 5950.000 ns
# scanning freq 5980.000 ns
# scanning freq 6010.000 ns
# scanning freq 6040.000 ns
# scanning freq 6070.000 ns
# scanning freq 6100.000 ns
# scanning freq 6130.000 ns
# scanning freq 6160.000 ns
# scanning freq 6190.000 ns
# scanning freq 6220.000 ns
# scanning freq 6250.000 ns
# scanning freq 6280.000 ns
# scanning freq 6310.000 ns
# scanning freq 6340.000 ns
# scanning freq 6370.000 ns
# scanning freq 6400.000 ns
# scanning freq 6430.000 ns
# scanning freq 6460.000 ns
# scanning freq 6490.000 ns
# scanning freq 6520.000 ns
# scanning freq 6550.000 ns
# scanning freq 6580.000 ns
# scanning freq 6610.000 ns
# scanning freq 6640.000 ns
# scanning freq 6670.000 ns
# scanning freq 6700.000 ns
# scanning freq 6730.000 ns
# scanning freq 6760.000 ns
# scanning freq 6790.000 ns
# scanning freq 6820.000 ns
# scanning freq 6850.000 ns
# scanning freq 6880.000 ns
# scanning freq 6910.000 ns
# scanning freq 6940.000 ns
# scanning freq 6970.000 ns
# scanning freq 7000.000 ns
# finished data acquisition
# two pulses: False
# Detailed data result has been saved into ../output/Ramsey-counts-with-ref-2022-02-18-86de9ee5-910b-11ec-abf6-046c59258eff.json
# Stopped: Scheduling process has stopped
# Closed: All instrument resources has been released

# %%
# observe detection sequence
scheduler._gene_pseudo_detect_seq()
fig = scheduler.sequences_figure

# %% [markdown]
# **3. Calculate contrast and plot figures**

# %%
## count & contrast
counts_sig_ref = scheduler.result  # [times, counts, counts_ref]
contrast = [sig / ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]
contrast_2 = [abs(sig - ref) / ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]

# %%
# plot_ramsey(counts_sig_ref[0], contrast)

plt.style.use('seaborn')
plt.plot(counts_sig_ref[0], counts_sig_ref[1], 'o-')
plt.plot(counts_sig_ref[0], counts_sig_ref[2], 'o-')
plt.title('Ramsey')
plt.xlabel('Duration time (ns)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.plot(counts_sig_ref[0][1:], contrast[1:], 'o-')
plt.title('Ramsey')
# Out:
# Text(0.5, 1.0, 'Ramsey')

# %%
plt.plot(counts_sig_ref[0][1:], contrast_2[1:], 'o-')
plt.title('Ramsey contrast')
# Out:
# Text(0.5, 1.0, 'Ramsey contrast')

# %%
np.savetxt('ramsey_2.852ghz_310ns.txt', scheduler.result)

# %% [markdown]
# ## Rabi oscillation

# %% [markdown]
# **1. Set measurement parameters**
# - number of readout operation $N$ per frequency measurement point
# - delay time range for scanning modes, i.e., `[t_start, t_end, t_step]`, unit: "ns"
# - laser initilization time $t_{init}$, singal readout pulse time $t_{sig}$, etc.
# - MW power $p$, MW frequency $f$
# - time bin $t$ per readout operation will be calculated dynamically when running the scheduler on scanning-time mode

# %%
t_start = 20
t_end = 2000
t_step = 30

t_init = 3e3
inter_init_mw = 3000
inter_mw_read = 200

t_read_sig = 800
pre_read = 50

N = int(1e6 / 4)

p = 12
f = 2.889 * C.giga

# %% [markdown]
# **2. Construct a Rabi measurement Scheduler and run**

# %%
scheduler = RabiScheduler(mw_ttl=1, with_ref=True, epoch_omit=5)
scheduler.configure_mw_paras(power=p, freq=f)
scheduler.configure_odmr_seq(t_init, t_read_sig, pre_read=pre_read, inter_init_mw=inter_init_mw,
                             inter_mw_read=inter_mw_read, N=N)
scheduler.set_delay_times(t_start, t_end, t_step)
scheduler.configure_tagger_counting(reader='cbm')
# Out:
# --- USE ASGDLL_x64.dll ---
# Current Tagger input channels: {'apd': 1, 'asg': 2}

# %%
scheduler.run_scanning()

scheduler.close()
# Out:
# Begin to run Rabi Scheduler. Time intervals: 20.000 - 2000.000 ns.
# N: 250000, n_times: 67
# Estimated total running time: 16.92 s
# MW on/off status: True
# scanning freq 20.000 ns (trivial)
# scanning freq 20.000 ns (trivial)
# scanning freq 20.000 ns (trivial)
# scanning freq 20.000 ns (trivial)
# scanning freq 20.000 ns (trivial)
# scanning time interval: 20.000 ns
# scanning time interval: 50.000 ns
# scanning time interval: 80.000 ns
# scanning time interval: 110.000 ns
# scanning time interval: 140.000 ns
# scanning time interval: 170.000 ns
# scanning time interval: 200.000 ns
# scanning time interval: 230.000 ns
# scanning time interval: 260.000 ns
# scanning time interval: 290.000 ns
# scanning time interval: 320.000 ns
# scanning time interval: 350.000 ns
# scanning time interval: 380.000 ns
# scanning time interval: 410.000 ns
# scanning time interval: 440.000 ns
# scanning time interval: 470.000 ns
# scanning time interval: 500.000 ns
# scanning time interval: 530.000 ns
# scanning time interval: 560.000 ns
# scanning time interval: 590.000 ns
# scanning time interval: 620.000 ns
# scanning time interval: 650.000 ns
# scanning time interval: 680.000 ns
# scanning time interval: 710.000 ns
# scanning time interval: 740.000 ns
# scanning time interval: 770.000 ns
# scanning time interval: 800.000 ns
# scanning time interval: 830.000 ns
# scanning time interval: 860.000 ns
# scanning time interval: 890.000 ns
# scanning time interval: 920.000 ns
# scanning time interval: 950.000 ns
# scanning time interval: 980.000 ns
# scanning time interval: 1010.000 ns
# scanning time interval: 1040.000 ns
# scanning time interval: 1070.000 ns
# scanning time interval: 1100.000 ns
# scanning time interval: 1130.000 ns
# scanning time interval: 1160.000 ns
# scanning time interval: 1190.000 ns
# scanning time interval: 1220.000 ns
# scanning time interval: 1250.000 ns
# scanning time interval: 1280.000 ns
# scanning time interval: 1310.000 ns
# scanning time interval: 1340.000 ns
# scanning time interval: 1370.000 ns
# scanning time interval: 1400.000 ns
# scanning time interval: 1430.000 ns
# scanning time interval: 1460.000 ns
# scanning time interval: 1490.000 ns
# scanning time interval: 1520.000 ns
# scanning time interval: 1550.000 ns
# scanning time interval: 1580.000 ns
# scanning time interval: 1610.000 ns
# scanning time interval: 1640.000 ns
# scanning time interval: 1670.000 ns
# scanning time interval: 1700.000 ns
# scanning time interval: 1730.000 ns
# scanning time interval: 1760.000 ns
# scanning time interval: 1790.000 ns
# scanning time interval: 1820.000 ns
# scanning time interval: 1850.000 ns
# scanning time interval: 1880.000 ns
# scanning time interval: 1910.000 ns
# scanning time interval: 1940.000 ns
# scanning time interval: 1970.000 ns
# scanning time interval: 2000.000 ns
# finished data acquisition
# two pulses: False
# Detailed data result has been saved into ../output/Rabi-counts-with-ref-2022-02-21-71eec4f9-9370-11ec-8123-046c59258eff.json
# Stopped: Scheduling process has stopped
# Closed: All instrument resources has been released

# %%
scheduler._gene_pseudo_detect_seq()
fig = scheduler.sequences_figure

# %% [markdown]
# **3. Calculate contrast and plot figures**

# %%
## count & contrast
counts_sig_ref = scheduler.result  # [times, counts, counts_ref]
contrast = [sig / ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]
contrast_2 = [abs(sig - ref) / ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]

# %%
# plot_rabi(counts_sig_ref[0], counts_sig_ref[1])
plt.style.use('seaborn')
#plt.vlines(210, 13.6,14)
plt.plot(counts_sig_ref[0], counts_sig_ref[1], 'o--', label='signal')
plt.plot(counts_sig_ref[0], counts_sig_ref[2], 'o-', label='referengce')
plt.legend()
plt.title('Rabi Oscillation')
plt.xlabel('MW time (ns)')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
plt.plot(counts_sig_ref[0][1:], contrast[1:], 'o-')

# %%
plt.plot(counts_sig_ref[0][1:], contrast_2[1:], 'o-')

# %%
np.savetxt('rabi_2.889ghz_12dbm_long_7us.txt', scheduler.result)

# %% [markdown]
# ## T1 relaxometry

# %% [markdown]
# **1. Set measurement parameters**
# - number of readout operation $N$ per frequency measurement point
# - delay time range for scanning modes, i.e., `[t_start, t_end, t_step]`, unit: "ns"
# - laser initialization time $t_{init}$, signal readout pulse time $t_{sig}$, etc.
# - calibrated MW $\pi$ pulse parameters, i.e., frequency (unit: Hz), power (unit: dBm) and time (unit: s)
# - optional parameters: MW power $p$, if designed, the time of built-in MW $\pi$ pulse will be regulated correspondingly
# - time bin $t$ per readout operation will be calculated dynamically when running the scheduler on scanning-time mode

# %%
t_start = int(1e4)
t_end = int(1e6)
t_step = int(1e4)

pi_power = 10
pi_freq = 2.852 * C.giga
pi_time = 210 * C.nano

t_init = 3e3
inter_init_mw = 1e3
t_read_sig = 800
t_read_ref = t_read_sig

N = int(1e6 / 4)

times = np.round(10 ** np.linspace(1, 5, 50)) * 10

# %% [markdown]
# **2. Construct a T1 measurement scheduler and run**

# %%
scheduler = RelaxationScheduler(mw_ttl=1, ms=0, epoch_omit=5)
scheduler.pi_pulse['freq'], scheduler.pi_pulse['power'], scheduler.pi_pulse['time'] = pi_freq, pi_power, pi_time
scheduler.configure_odmr_seq(t_init, t_read_sig, inter_init_mw=inter_init_mw, N=N)
scheduler.set_delay_times(t_start, t_end, t_step)
scheduler.set_delay_times(times=times)
scheduler.configure_tagger_counting(reader='cbm')

print('scheduler for detecting relaxation time of state Ms={}'.format(scheduler.ms))
# Out:
# --- USE ASGDLL_x64.dll ---
# Current Tagger input channels: {'apd': 1, 'asg': 2}
# 0

# %%
scheduler.run_scanning()
scheduler.close()
# Out:
# Begin to run T1 Relaxation Scheduler. Time intervals: 100.000 - 1000000.000 ns.
# N: 250000, n_times: 50
# Estimated total running time: 1458.83 s
# MW on/off status: True
# ms == 0
# no two-pulse read
# scanning freq 100.000 ns
# ms == 0
# no two-pulse read
# scanning freq 120.000 ns
# ms == 0
# no two-pulse read
# scanning freq 150.000 ns
# ms == 0
# no two-pulse read
# scanning freq 180.000 ns
# ms == 0
# no two-pulse read
# scanning freq 210.000 ns
# ms == 0
# no two-pulse read
# scanning freq 260.000 ns
# ms == 0
# no two-pulse read
# scanning freq 310.000 ns
# ms == 0
# no two-pulse read
# scanning freq 370.000 ns
# ms == 0
# no two-pulse read
# scanning freq 450.000 ns
# ms == 0
# no two-pulse read
# scanning freq 540.000 ns
# ms == 0
# no two-pulse read
# scanning freq 660.000 ns
# ms == 0
# no two-pulse read
# scanning freq 790.000 ns
# ms == 0
# no two-pulse read
# scanning freq 950.000 ns
# ms == 0
# no two-pulse read
# scanning freq 1150.000 ns
# ms == 0
# no two-pulse read
# scanning freq 1390.000 ns
# ms == 0
# no two-pulse read
# scanning freq 1680.000 ns
# ms == 0
# no two-pulse read
# scanning freq 2020.000 ns
# ms == 0
# no two-pulse read
# scanning freq 2440.000 ns
# ms == 0
# no two-pulse read
# scanning freq 2950.000 ns
# ms == 0
# no two-pulse read
# scanning freq 3560.000 ns
# ms == 0
# no two-pulse read
# scanning freq 4290.000 ns
# ms == 0
# no two-pulse read
# scanning freq 5180.000 ns
# ms == 0
# no two-pulse read
# scanning freq 6250.000 ns
# ms == 0
# no two-pulse read
# scanning freq 7540.000 ns
# ms == 0
# no two-pulse read
# scanning freq 9100.000 ns
# ms == 0
# no two-pulse read
# scanning freq 10990.000 ns
# ms == 0
# no two-pulse read
# scanning freq 13260.000 ns
# ms == 0
# no two-pulse read
# scanning freq 16000.000 ns
# ms == 0
# no two-pulse read
# scanning freq 19310.000 ns
# ms == 0
# no two-pulse read
# scanning freq 23300.000 ns
# ms == 0
# no two-pulse read
# scanning freq 28120.000 ns
# ms == 0
# no two-pulse read
# scanning freq 33930.000 ns
# ms == 0
# no two-pulse read
# scanning freq 40950.000 ns
# ms == 0
# no two-pulse read
# scanning freq 49420.000 ns
# ms == 0
# no two-pulse read
# scanning freq 59640.000 ns
# ms == 0
# no two-pulse read
# scanning freq 71970.000 ns
# ms == 0
# no two-pulse read
# scanning freq 86850.000 ns
# ms == 0
# no two-pulse read
# scanning freq 104810.000 ns
# ms == 0
# no two-pulse read
# scanning freq 126490.000 ns
# ms == 0
# no two-pulse read
# scanning freq 152640.000 ns
# ms == 0
# no two-pulse read
# scanning freq 184210.000 ns
# ms == 0
# no two-pulse read
# scanning freq 222300.000 ns
# ms == 0
# no two-pulse read
# scanning freq 268270.000 ns
# ms == 0
# no two-pulse read
# scanning freq 323750.000 ns
# ms == 0
# no two-pulse read
# scanning freq 390690.000 ns
# ms == 0
# no two-pulse read
# scanning freq 471490.000 ns
# ms == 0
# no two-pulse read
# scanning freq 568990.000 ns
# ms == 0
# no two-pulse read
# scanning freq 686650.000 ns
# ms == 0
# no two-pulse read
# scanning freq 828640.000 ns
# ms == 0
# no two-pulse read
# scanning freq 1000000.000 ns
# finished data acquisition
# two pulses: False
# ------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2348/3944735443.py in <module>
# ----> 1 scheduler.run_scanning()
#       2 scheduler.close()
#       3
#       4
#
# D:\Git-Project\odmactor\odmactor\scheduler\base.py in run_scanning(self)
#     660
#     661         self._start_device()
# --> 662         self._acquire_data()  # scanning time intervals in this loop
#     663         self.stop()
#     664
#
# D:\Git-Project\odmactor\odmactor\scheduler\base.py in _acquire_data(self, *args, **kwargs)
#     647
#     648         # 3. save result
# --> 649         self.save_result(self._gene_data_result_fname())
#     650
#     651     def run_scanning(self):
#
# D:\Git-Project\odmactor\odmactor\scheduler\base.py in save_result(self, fname)
#     368                                  '{}-result-{}-{}'.format(self.name, str(datetime.date.today()), uuid.uuid1()))
#     369         with open(fname + '.json', 'w') as f:
# --> 370             json.dump(self._result_detail, f)
#     371         print('Detailed data result has been saved into {}'.format(fname + '.json'))
#     372
#
# ~\miniconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~\miniconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# ~\miniconda3\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\miniconda3\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# ~\miniconda3\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type ndarray is not JSON serializable

# %%
# observe sequence figure
fig = scheduler.sequences_figure

# %% [markdown]
# **3. Calculate contrast and plot figures**

# %%
## count & contrast
counts_sig_ref = scheduler.result  # [times, counts, counts_ref]
contrast = [sig / ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2348/1828699904.py in <module>
#       1 ## count & contrast
#       2 counts_sig_ref = scheduler.result  # [times, counts, counts_ref]
# ----> 3 contrast = [sig/ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]
#       4
#
# IndexError: list index out of range

# %%
plot_t1(counts_sig_ref[0], contrast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2348/1737635237.py in <module>
# ----> 1 plot_t1(counts_sig_ref[0], contrast)
#       2
#
# NameError: name 'contrast' is not defined

# %% [markdown]
# ## Hahn echo measurement

# %%
t_start = 40
t_end = 7000
t_step = 30

pi_power = 12
pi_freq = 2.852 * C.giga
pi_time = 310 * C.nano

t_init = 5e3
inter_init_mw = 3e3
inter_mw_read = 200
pre_read = 50
t_read_sig = 800
# t_read_ref = t_read_sig

N = int(1e6 / 4)
# Out:
# --- USE ASGDLL_x64.dll ---
# Current Tagger input channels: {'apd': 1, 'asg': 2}

# %% [markdown]
# **2. Construct a Hahn echo measurement Scheduler and run**

# %%
scheduler = HahnEchoScheduler(mw_ttl=0, with_ref=True, epoch_omit=5)
scheduler.configure_mw_paras(power=pi_power, freq=pi_freq)
scheduler.pi_pulse['time'], scheduler.pi_pulse['freq'], scheduler.pi_pulse['power'] = pi_time, pi_freq, pi_power
scheduler.configure_odmr_seq(t_init, t_read_sig, inter_init_mw, inter_mw_read, pre_read, N=N)
scheduler.set_delay_times(t_start,t_end,t_step)
scheduler.configure_tagger_counting(reader='cbm')

# %%
scheduler.run_scanning()
scheduler.close()
# Out:
# Begin to run Time-domain ODMR Scheduler. Time intervals: 40.000 - 7000.000 ns.
# N: 250000, n_times: 233
# Estimated total running time: 205.04 s
# MW on/off status: True
# scanning freq 40.000 ns
# scanning freq 70.000 ns
# scanning freq 100.000 ns
# scanning freq 130.000 ns
# scanning freq 160.000 ns
# scanning freq 190.000 ns
# scanning freq 220.000 ns
# scanning freq 250.000 ns
# scanning freq 280.000 ns
# scanning freq 310.000 ns
# scanning freq 340.000 ns
# scanning freq 370.000 ns
# scanning freq 400.000 ns
# scanning freq 430.000 ns
# scanning freq 460.000 ns
# scanning freq 490.000 ns
# scanning freq 520.000 ns
# scanning freq 550.000 ns
# scanning freq 580.000 ns
# scanning freq 610.000 ns
# scanning freq 640.000 ns
# scanning freq 670.000 ns
# scanning freq 700.000 ns
# scanning freq 730.000 ns
# scanning freq 760.000 ns
# scanning freq 790.000 ns
# scanning freq 820.000 ns
# scanning freq 850.000 ns
# scanning freq 880.000 ns
# scanning freq 910.000 ns
# scanning freq 940.000 ns
# scanning freq 970.000 ns
# scanning freq 1000.000 ns
# scanning freq 1030.000 ns
# scanning freq 1060.000 ns
# scanning freq 1090.000 ns
# scanning freq 1120.000 ns
# scanning freq 1150.000 ns
# scanning freq 1180.000 ns
# scanning freq 1210.000 ns
# scanning freq 1240.000 ns
# scanning freq 1270.000 ns
# scanning freq 1300.000 ns
# scanning freq 1330.000 ns
# scanning freq 1360.000 ns
# scanning freq 1390.000 ns
# scanning freq 1420.000 ns
# scanning freq 1450.000 ns
# scanning freq 1480.000 ns
# scanning freq 1510.000 ns
# scanning freq 1540.000 ns
# scanning freq 1570.000 ns
# scanning freq 1600.000 ns
# scanning freq 1630.000 ns
# scanning freq 1660.000 ns
# scanning freq 1690.000 ns
# scanning freq 1720.000 ns
# scanning freq 1750.000 ns
# scanning freq 1780.000 ns
# scanning freq 1810.000 ns
# scanning freq 1840.000 ns
# scanning freq 1870.000 ns
# scanning freq 1900.000 ns
# scanning freq 1930.000 ns
# scanning freq 1960.000 ns
# scanning freq 1990.000 ns
# scanning freq 2020.000 ns
# scanning freq 2050.000 ns
# scanning freq 2080.000 ns
# scanning freq 2110.000 ns
# scanning freq 2140.000 ns
# scanning freq 2170.000 ns
# scanning freq 2200.000 ns
# scanning freq 2230.000 ns
# scanning freq 2260.000 ns
# scanning freq 2290.000 ns
# scanning freq 2320.000 ns
# scanning freq 2350.000 ns
# scanning freq 2380.000 ns
# scanning freq 2410.000 ns
# scanning freq 2440.000 ns
# scanning freq 2470.000 ns
# scanning freq 2500.000 ns
# scanning freq 2530.000 ns
# scanning freq 2560.000 ns
# scanning freq 2590.000 ns
# scanning freq 2620.000 ns
# scanning freq 2650.000 ns
# scanning freq 2680.000 ns
# scanning freq 2710.000 ns
# scanning freq 2740.000 ns
# scanning freq 2770.000 ns
# scanning freq 2800.000 ns
# scanning freq 2830.000 ns
# scanning freq 2860.000 ns
# scanning freq 2890.000 ns
# scanning freq 2920.000 ns
# scanning freq 2950.000 ns
# scanning freq 2980.000 ns
# scanning freq 3010.000 ns
# scanning freq 3040.000 ns
# scanning freq 3070.000 ns
# scanning freq 3100.000 ns
# scanning freq 3130.000 ns
# scanning freq 3160.000 ns
# scanning freq 3190.000 ns
# scanning freq 3220.000 ns
# scanning freq 3250.000 ns
# scanning freq 3280.000 ns
# scanning freq 3310.000 ns
# scanning freq 3340.000 ns
# scanning freq 3370.000 ns
# scanning freq 3400.000 ns
# scanning freq 3430.000 ns
# scanning freq 3460.000 ns
# scanning freq 3490.000 ns
# scanning freq 3520.000 ns
# scanning freq 3550.000 ns
# scanning freq 3580.000 ns
# scanning freq 3610.000 ns
# scanning freq 3640.000 ns
# scanning freq 3670.000 ns
# scanning freq 3700.000 ns
# scanning freq 3730.000 ns
# scanning freq 3760.000 ns
# scanning freq 3790.000 ns
# scanning freq 3820.000 ns
# scanning freq 3850.000 ns
# scanning freq 3880.000 ns
# scanning freq 3910.000 ns
# scanning freq 3940.000 ns
# scanning freq 3970.000 ns
# scanning freq 4000.000 ns
# scanning freq 4030.000 ns
# scanning freq 4060.000 ns
# scanning freq 4090.000 ns
# scanning freq 4120.000 ns
# scanning freq 4150.000 ns
# scanning freq 4180.000 ns
# scanning freq 4210.000 ns
# scanning freq 4240.000 ns
# scanning freq 4270.000 ns
# scanning freq 4300.000 ns
# scanning freq 4330.000 ns
# scanning freq 4360.000 ns
# scanning freq 4390.000 ns
# scanning freq 4420.000 ns
# scanning freq 4450.000 ns
# scanning freq 4480.000 ns
# scanning freq 4510.000 ns
# scanning freq 4540.000 ns
# scanning freq 4570.000 ns
# scanning freq 4600.000 ns
# scanning freq 4630.000 ns
# scanning freq 4660.000 ns
# scanning freq 4690.000 ns
# scanning freq 4720.000 ns
# scanning freq 4750.000 ns
# scanning freq 4780.000 ns
# scanning freq 4810.000 ns
# scanning freq 4840.000 ns
# scanning freq 4870.000 ns
# scanning freq 4900.000 ns
# scanning freq 4930.000 ns
# scanning freq 4960.000 ns
# scanning freq 4990.000 ns
# scanning freq 5020.000 ns
# scanning freq 5050.000 ns
# scanning freq 5080.000 ns
# scanning freq 5110.000 ns
# scanning freq 5140.000 ns
# scanning freq 5170.000 ns
# scanning freq 5200.000 ns
# scanning freq 5230.000 ns
# scanning freq 5260.000 ns
# scanning freq 5290.000 ns
# scanning freq 5320.000 ns
# scanning freq 5350.000 ns
# scanning freq 5380.000 ns
# scanning freq 5410.000 ns
# scanning freq 5440.000 ns
# scanning freq 5470.000 ns
# scanning freq 5500.000 ns
# scanning freq 5530.000 ns
# scanning freq 5560.000 ns
# scanning freq 5590.000 ns
# scanning freq 5620.000 ns
# scanning freq 5650.000 ns
# scanning freq 5680.000 ns
# scanning freq 5710.000 ns
# scanning freq 5740.000 ns
# scanning freq 5770.000 ns
# scanning freq 5800.000 ns
# scanning freq 5830.000 ns
# scanning freq 5860.000 ns
# scanning freq 5890.000 ns
# scanning freq 5920.000 ns
# scanning freq 5950.000 ns
# scanning freq 5980.000 ns
# scanning freq 6010.000 ns
# scanning freq 6040.000 ns
# scanning freq 6070.000 ns
# scanning freq 6100.000 ns
# scanning freq 6130.000 ns
# scanning freq 6160.000 ns
# scanning freq 6190.000 ns
# scanning freq 6220.000 ns
# scanning freq 6250.000 ns
# scanning freq 6280.000 ns
# scanning freq 6310.000 ns
# scanning freq 6340.000 ns
# scanning freq 6370.000 ns
# scanning freq 6400.000 ns
# scanning freq 6430.000 ns
# scanning freq 6460.000 ns
# scanning freq 6490.000 ns
# scanning freq 6520.000 ns
# scanning freq 6550.000 ns
# scanning freq 6580.000 ns
# scanning freq 6610.000 ns
# scanning freq 6640.000 ns
# scanning freq 6670.000 ns
# scanning freq 6700.000 ns
# scanning freq 6730.000 ns
# scanning freq 6760.000 ns
# scanning freq 6790.000 ns
# scanning freq 6820.000 ns
# scanning freq 6850.000 ns
# scanning freq 6880.000 ns
# scanning freq 6910.000 ns
# scanning freq 6940.000 ns
# scanning freq 6970.000 ns
# scanning freq 7000.000 ns
# finished data acquisition
# two pulses: False
# Detailed data result has been saved into ../output/Time-domain-counts-with-ref-2022-02-18-44f2b969-9117-11ec-9d1e-046c59258eff.json
# Stopped: Scheduling process has stopped

# %% [markdown]
# **3. Calculate contrast and plot figures**

# %%
counts_sig_ref = scheduler.result  # [times, counts, counts_ref]
contrast = [sig / ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]
contrast_2 = [abs(sig - ref) / ref for sig, ref in zip(counts_sig_ref[1], counts_sig_ref[2])]

# %%
# plot_rabi(counts_sig_ref[0], counts_sig_ref[1])
plt.style.use('seaborn')
#plt.vlines(210, 13.6,14)
plt.plot(counts_sig_ref[0], counts_sig_ref[1], 'o--', label='signal')
plt.plot(counts_sig_ref[0], counts_sig_ref[2], 'o-', label='referengce')
plt.legend()
plt.title('Hahn echo')
plt.xlabel('MW time (ns)')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
plt.plot(counts_sig_ref[0][1:], contrast[1:], 'o-')

# %%
plt.plot(counts_sig_ref[0][1:], contrast_2[1:], 'o-')
